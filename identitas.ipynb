# %% [markdown]
# <a href="https://colab.research.google.com/github/anggitaputri13/anggita/blob/main/identitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nama = Anggita Putri Rahayu")
#menampilkan nama
print("NPM = 2605060005")
#menampilkan NPM
print("Tempat, Tanggal Lahir = Temanggung, 13 Desember 2007")
#menampilkan Tempat, Tanggal Lahir
print("Alamat = Muntung, Candoroto, Temanggung, Jawa Tengah")
#menampilkan Alamat
print("Jenis Kelamin = Perempuan")
#menampilkan Jenis Kelamin
print("Hobi = Scroll TikTok, Nyanyi, Rebahan, Jalan jalan")
#menampilkan hobi
print("Nama saya Anggita.")
#menampilkan tipe data String, yaitu data yang berisi teks atau kalimat
print(2007)
#menampilkan tipe data Integer, yaitu data yang berisi bilangan
print("Halo, saya Anggita")
#menampilkan contoh penggunaan print(), yang digunakan untuk menampilkan sesuatu ke output
print("# digunakan untuk memberikan komentar atau keterangan pada kode yang tidak akan dijalankan")
#menampilkan fungsi#
# Out:
# Nama = Anggita Putri Rahayu
# NPM = 2605060005
# Tempat, Tanggal Lahir = Temanggung, 13 Desember 2007
# Alamat = Muntung, Candoroto, Temanggung, Jawa Tengah
# Jenis Kelamin = Perempuan
# Hobi = Scroll TikTok, Nyanyi, Rebahan, Jalan jalan
# Nama saya Anggita.
# 2007
# Halo, saya Anggita
# # digunakan untuk memberikan komentar atau keterangan pada kode yang tidak akan dijalankan
